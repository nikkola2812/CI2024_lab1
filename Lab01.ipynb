# %% [markdown]
# ## Lab 01 - Set Covers Problem

# %%
from itertools import accumulate
from random import random, seed
import numpy as np
from icecream import ic
from matplotlib import pyplot as plt
from tqdm.auto import tqdm

# %% [markdown]
# Instance 1

# %%
UNIVERSE_SIZE = 100
NUM_SETS = 10
DENSITY = 0.2

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %%
def valid(solution):
    """Checks wether solution is valid (ie. covers all universe)"""
    return np.all(np.logical_or.reduce(SETS[solution]))


def cost(solution):
    """Returns the cost of a solution (to be minimized)"""
    return COSTS[solution].sum()

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Current Cost: 138.0097370393868
# Index of Current Cost in History: 0

# %%
UNIVERSE_SIZE = 1_000
NUM_SETS = 100
DENSITY = 0.2

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %% [markdown]
# Instance 2

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Current Cost: 6906.190709310941
# Index of Current Cost in History: 763

# %% [markdown]
# Instance 3

# %%
UNIVERSE_SIZE = 10_000
NUM_SETS = 1_000
DENSITY = 0.2

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Current Cost: 1395841.448128317
# Index of Current Cost in History: 984

# %% [markdown]
# Instance 4

# %%
UNIVERSE_SIZE = 100_000
NUM_SETS = 10_000
DENSITY = 0.1

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Current Cost: 119490140.82418334
# Index of Current Cost in History: 999

# %% [markdown]
# Instance 5

# %%
UNIVERSE_SIZE = 100_000
NUM_SETS = 10_000
DENSITY = 0.2

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Current Cost: 258215247.71670544
# Index of Current Cost in History: 995

# %% [markdown]
# Instance 6

# %%
UNIVERSE_SIZE = 100_000
NUM_SETS = 10_000
DENSITY = 0.3

rng = np.random.Generator(np.random.PCG64([UNIVERSE_SIZE, NUM_SETS, int(10_000 * DENSITY)]))

# %%
SETS = np.random.random((NUM_SETS, UNIVERSE_SIZE)) < DENSITY
for s in range(UNIVERSE_SIZE):
    if not np.any(SETS[:, s]):
        SETS[np.random.randint(NUM_SETS), s] = True
        
COSTS = np.power(SETS.sum(axis=1), 1.1)

# %%
current_solution = rng.random(NUM_SETS) < .5
current_cost = cost(current_solution)
history = [current_cost]

for _ in tqdm(range(1_000)):
    neighbor = current_solution.copy()

    if np.random.rand() < .4:
        i = np.random.randint(0, NUM_SETS)
        neighbor[i] = not neighbor[i]

    neighbor_cost = cost(neighbor)
    history.append(neighbor_cost)

    if valid(neighbor) and neighbor_cost < current_cost:
        current_solution = neighbor
        current_cost = neighbor_cost


print(f"Current Cost: {current_cost}")
print(f"Index of Current Cost in History: {history.index(current_cost)}")
plt.figure(figsize=(14, 8))
plt.title(f"RMHC with Random Mutation\nUNIVERSE_SIZE={UNIVERSE_SIZE}, NUM_SETS={NUM_SETS}, DENSITY={DENSITY}")
plt.xlabel("Iteration")
plt.ylabel("Fitness")
plt.plot(
    range(len(history)),
    list(accumulate(history, max)),
    color="red",
)
_ = plt.scatter(range(len(history)), history, marker=".")
plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
